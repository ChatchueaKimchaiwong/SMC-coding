# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.stats import norm
import math
import sympy
from numpy.linalg import inv
from sympy import diff
from sympy import Symbol
import time

# %%
def prediction(x, F, sqrtU):
    return np.matmul(F, x) + np.matmul(sqrtU, np.random.randn(sqrtU.shape[1]))

def observation(x, H, sqrtV):
    return np.matmul(H, x) + np.matmul(sqrtV, np.random.randn(sqrtV.shape[1]))

def generate_data(F, H, sqrtU, sqrtV, n, xdim, ydim):
    x = np.zeros((xdim, n))
    y = np.zeros((ydim, n))
    x[:, 0] = prediction(x0, F, sqrtU) #state time 1
    y[:, 0] = observation(x[:, 0], H, sqrtV) #ob time 1
    for k in range(1,n):
        x[:, k] = prediction(x[:, k-1], F, sqrtU)
        y[:, k] = observation(x[:, k], H, sqrtV)
    return x, y

def Kalman_filter(y, m0, P0, F, H, U, V, n, xdim, delta):
    # Updated mean and variance
    mu = np.zeros((xdim, n))
    Pu = np.zeros((xdim, xdim, n))
    # Predicted mean and variance
    mp = np.zeros((xdim, n))
    Pp = np.zeros((xdim, xdim, n))
    
    # Predicted mean and variance t=1
    mp[:, 0] = np.matmul(F, m0)
    Pp[:, :, 0] = np.matmul(np.matmul(F, P0), F.transpose()) + U
    
    # Updated mean and variance t=1
    z = y[:, 0] - np.matmul(H, mp[:, 0])
    S = np.matmul(np.matmul(H, Pp[:, :, 0]), H.transpose()) + V
    K = np.matmul(np.matmul(Pp[:, :, 0], H.transpose()), inv(S))
    mu[:, 0] = mp[:, 0] + np.matmul(K, z)
    Pu[:, :, 0] = np.matmul(np.eye(xdim) - np.matmul(K, H), Pp[:, :, 0])
    
    # Kalman filter t=2-n
    for k in np.arange(1,n):
        # Prediction
        mp[:, k] = np.matmul(F, mu[:, k-1])
        Pp[:, :, k] = np.matmul(np.matmul(F, Pu[:, :, k-1]), F.transpose()) + U
        # Update
        if k < n - delta:
            z = y[:, k] - np.matmul(H, mp[:, k])
            S = np.matmul(np.matmul(H, Pp[:, :, k]), H.transpose()) + V
            K = np.matmul(np.matmul(Pp[:, :, k], H.transpose()), inv(S))
            mu[:, k] = mp[:, k] + np.matmul(K, z)
            Pu[:, :, k] = np.matmul(np.eye(xdim) - np.matmul(K, H), Pp[:, :, k])
        else:
            mu[:, k] = mp[:, k]
            Pu[:, :, k] = Pp[:, :, k]
        
    return mp, Pp, mu, Pu


#matrix of transformation for p(x0,x1,...,xn) => p(y1,...,yn)
def genH(H,n):
    Hv = np.zeros((n, n+1))
    for i in np.arange(n):
        Hv[i][i+1] = H
    return Hv

#matrix of mean of joint prior p(x0,x1,...,xn)
def genM(F,m0,n):
    M = []    
    M.append(m0)
    for i in np.arange(n):
        M.append(np.matmul(F,M[i]))
    M = np.array(M)  #array of old mean
    return M
    
#matrix of variance of joint prior p(x0,x1,...,xn)
def genP(F,P0,U,n):
    P = np.zeros((n+1, n+1))
    P[0][0] = P0
    for i in np.arange(1,n+1):
        P[i][i] = np.matmul(np.matmul(F, [P[i-1][i-1]]), F.transpose()) + U
    for j in np.arange(0,n+1):    
        for k in np.arange(0,n+1):  
            if j < k:
                P[j][k] =  np.matmul(F, [P[j][k-1]])
                P[k][j] = P[j][k]
    return P

def KS(y,m0,P0,F,H,U,V,n,start,end):
    Mu0 = np.zeros(n) #mean x0|y1:n when n=1,...,n
    P00 = np.zeros(n) #var x0|y1:n when n=1,...,n
    Mun = np.zeros(n) #mean xn|y1:n when n=1,...,n
    Pnn = np.zeros(n) #var xn|y1:n when n=1,...,n
    P0n = np.zeros(n) #cov x0,xn|y1:n when n=1,...,n
    Mcco = np.zeros(n) #coef of mean xn|x0,y1:n 
    Mcre = np.zeros(n) #remainder of mean xn|x0,y1:n 
    Pc = np.zeros(n) #var of xn|x0,y1:n 
    for h in np.arange(start,end+1):
        P = genP(F,P0,U,h)
        Hv = genH(H,h)
        Vv = np.zeros((h, h))
        for i in np.arange(h):
            Vv[i][i] = V
        S = np.matmul(np.matmul(Hv, P),Hv.transpose()) +Vv
        K = np.matmul(np.matmul(P, Hv.transpose()),inv(S)) 
        M = genM(F,m0,h)
        Mu0[h-1] = np.matmul((np.identity(h+1) - np.matmul(K,Hv))[0], M) + np.matmul(K[0],y[0][0:h]) #mean x0|y1:n
        Mun[h-1] = np.matmul((np.identity(h+1) - np.matmul(K,Hv))[h], M) + np.matmul(K[h],y[0][0:h]) #mean xn|y1:n
        P00[h-1] = np.matmul((np.identity(h+1) - np.matmul(K,Hv))[0],P[:,[0]])
        P0n[h-1] = np.matmul((np.identity(h+1) - np.matmul(K,Hv))[0],P[:,[h]])
        Pnn[h-1] = np.matmul((np.identity(h+1) - np.matmul(K,Hv))[h],P[:,[h]])
        Mcco[h-1] = P0n[h-1]/P00[h-1]
        Mcre[h-1] = Mun[h-1] - (Mcco[h-1]* Mu0[h-1])
        Pc[h-1] = Pnn[h-1] - (Mcco[h-1]*P0n[h-1])
    return Mu0,P00,Mun,Pnn,Mcco,Mcre,Pc

# %%
# Dimensions of the state and observation
xdim = 1
ydim = 1

# Initial state
x0 = np.array([[0]])

# Observation matrix = N(yn;xn,1)
H = np.array([[1]]) #identity observe

# Observation noise
sigy=20  #sigy = 20
sqrtV = np.array([[sigy]]) #sigma ob
V = np.matmul(sqrtV, sqrtV.transpose()) #observation variance

# Prior = N(x0;0,1)
m0 = np.array([0.0]) #m0=0
sig0 =400 #prior sigma , sig0=400
P0 = np.array([sig0**2]) #large uncertainty of initial state sig0^2 

# Evolution = N(xn+1;xn,1)
dt = 1.0
F = np.array([[1]]) #identity evolution
sigx = 1 #sigx=1
sqrtU = np.array([[sigx]]) #sigma evolve
U = np.matmul(sqrtU, sqrtU.transpose()) #variance evolve
# Time steps
n = 50
delta = 0 

# Data generation
(x, y) = generate_data(F, H, sqrtU, sqrtV, n, xdim, ydim)

# %%
(Mu0,P00,Mun,Pnn,Mcco,Mcre,Pc) = KS(y,m0,P0,F,H,U,V,n,1,n)

a=-2
b=2

#rv-rv case
cred = norm(Mun, Pnn**0.5).cdf(b) - norm(Mun, Pnn**0.5).cdf(a) 

#duv-duv case
B = [] #maximum value of function = credibility duv-duv case
for i in np.arange(n):
    if a <= Mun[i] <= b:
        B.append(1)
    elif Mun[i] < a:
        B.append(math.exp((-1/(2*(Pnn[i])))*((a-Mun[i])**2 ))) #f(a)
    else :
        B.append(math.exp((-1/(2*(Pnn[i])))*((b-Mun[i])**2 ))) #f(b)
        
X = [] #lower bound for credibility duv-duv case
for i in np.arange(n):
    if a <= Mun[i] <= b:
        if abs(a-Mun[i]) <= abs(b-Mun[i]):
            X.append(1-(math.exp((-1/(2*(Pnn[i])))*((a-Mun[i])**2 )))) #1-f(a)
        else :
            X.append(1-(math.exp((-1/(2*(Pnn[i])))*((b-Mun[i])**2 )))) #1-f(b)
    elif Mun[i] < a:
        X.append(0) #1-f(mean)
    else :
        X.append(0) #1-f(mean)
        
#duv-rv case
D = [] #maximum value of function = credibility duv-rv case
for i in np.arange(n):
    def f(x):
        return (math.exp((-1/(2*P00[i]))*((x-Mu0[i])**2 )))* (norm(Mcco[i]*x + Mcre[i], Pc[i]**0.5).cdf(b) - 
                                                      norm(Mcco[i]*x + Mcre[i], Pc[i]**0.5).cdf(a))
    fj1= f((minimize(lambda x: -f(x),a)).x) #set intial guess =a(left point of interval) 
    fj2= f((minimize(lambda x: -f(x),b)).x) #set intial guess =b(right point of interval)
    fj= max(fj1,fj2) 
    D.append(fj[0])  

Y = [] #lower bound for credibility duv-rv case
for i in np.arange(n):
    def f(x):
        return 1- ((math.exp((-1/(2*P00[i]))*((x-Mu0[i])**2 )))* (1 - norm(Mcco[i]*x + Mcre[i], Pc[i]**0.5).cdf(b) + 
                                                          norm(Mcco[i]*x + Mcre[i], Pc[i]**0.5).cdf(a)))
    fj1= f((minimize(f,a)).x) #set intial guess =a(left point of interval) 
    fj2= f((minimize(f,b)).x) #set intial guess =b(right point of interval) 
    fj= min(fj1,fj2) 
    Y.append(fj[0])

# %%
plt.figure(figsize=(30,10))
plt.title("Credibility of $P(X_n \in (-2,2)| y_{1:n})$ for different types of uncertainty when $\sigma_{x_{0}} = 400, \sigma_{x}=1,\sigma_{y}=20$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('credibility', fontsize=20)
plt.plot(np.arange(start=1, stop=n+1, step=1),cred,linestyle='-',color='blue',label='rv-rv')
plt.plot(np.arange(start=1, stop=n+1, step=1),B,linestyle='dashed',color='red')
plt.plot(np.arange(start=1, stop=n+1, step=1),X,linestyle='dotted',color='red')
plt.plot(np.arange(start=1, stop=n+1, step=1),D,linestyle='dashed',color='purple')
plt.plot(np.arange(start=1, stop=n+1, step=1),Y,linestyle='dotted',color='purple')
plt.fill_between(np.arange(start=1, stop=n+1, step=1),B,X, color='red', alpha=0.1,label='range of duv-duv')
plt.fill_between(np.arange(start=1, stop=n+1, step=1),D,Y, color='purple', alpha=0.1,label='range of duv-rv')
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# # Comparison of using time for finding p(xn|y1:n,x0) between KF iteration and KS with marginalization

# %% [markdown]
# ### Traditional method (KF iteration)

# %%
start1 = time.time()
mp = [np.matmul(F,[Symbol('x')])] #m1|0
Pp = np.zeros((xdim, xdim, n))
Pp[:, :, 0] = np.array([sigx**2]) #var1|0
mu=[]
Pu = np.zeros((xdim, xdim, n))

# Updated mean and variance t=1
z = y[:, 0] - np.matmul(H, mp[0])
S = np.matmul(np.matmul(H, Pp[:, :, 0]), H.transpose()) + V
K = np.matmul(np.matmul(Pp[:, :, 0], H.transpose()), inv(S))
mu.append(mp[0]+ np.matmul(K, z))
Pu[:, :, 0] = np.matmul(np.eye(xdim) - np.matmul(K, H), Pp[:, :, 0])

# Kalman filter t=2-n
for k in np.arange(1,n):
    # Prediction
    mp.append(np.matmul(F, mu[k-1]))
    Pp[:, :, k] = np.matmul(np.matmul(F, Pu[:, :, k-1]), F.transpose()) + U
    # Update
    if k < n - delta:
        z = y[:, k] - np.matmul(H, mp[k])
        S = np.matmul(np.matmul(H, Pp[:, :, k]), H.transpose()) + V
        K = np.matmul(np.matmul(Pp[:, :, k], H.transpose()), inv(S))
        mu.append(mp[k] + np.matmul(K, z))
        Pu[:, :, k] = np.matmul(np.eye(xdim) - np.matmul(K, H), Pp[:, :, k])
    else:
        mu.append(mp[k])
        Pu[:, :, k] = Pp[:, :, k]

#coefficient and remainder of x0 for mean of every time step 
#m = coef*x0 + rem
Coef =[]
Rem = []
for i in np.arange(n):
    coef = mu[i][0].diff(Symbol('x'))
    rem = mu[i][0] - (coef*Symbol('x'))
    Coef.append(float(coef))
    Rem.append(float(rem))
end1 = time.time()
timeuse1 = end1 -start1

# %% [markdown]
# ### Update 1 step method (Kalman Smoothing) to find only time step n

# %%
start2 = time.time()
KS(y,m0,P0,F,H,U,V,n,1,n)
end2 = time.time()
timeuse2 = end2 -start2

# %% [markdown]
# ### Update 1 step method (Kalman Smoothing) to find every time step

# %%
start3 = time.time()
KS(y,m0,P0,F,H,U,V,n,n,n)
end3 = time.time()
timeuse3 = end3 -start3

# %% [markdown]
# When finding $P(x_k | x_{0}, y_{1:k})$ for every timestep $k = 1, \ldots 200$,

# %%
print("KF spends time", timeuse1, "seconds, while KS spends time", timeuse2, "seconds.")
# Out:
# KF spends time 0.08178305625915527 seconds, while KS spends time 0.21242952346801758 seconds.

# %% [markdown]
# However, if we want to find $P(x_{200} | x_{0}, y_{1:200})$ only,

# %%
print("KS spends time", timeuse3, "seconds")
# Out:
# KS spends time 0.016952991485595703 seconds

# %% [markdown]
# # Range of subjective predictive distribution of observation $p(y_n |y_{1:n-1})$
#
# From Kalman Filter, we get the predictive distribution of state at time n : $p(x_n-1 |y_{1:n-1},x_0) = \mathcal{N}(x_{n-1};\mu_{n-1}(x_0),\sigma_{n-1}^2)$.<br>
# Then, we can have $p(x_n |y_{1:n-1},x_0) = \mathcal{N}(x_{n};F\mu_{n-1}(x_0),F\sigma_{n-1}^2F^T + \sigma_x^2)$.<br>
# Moreover, from the fact $p(y_n |x_n) = \mathcal{N}(y_n;Hx_n,\sigma_y^2)$. <br>
# Then, $p(y_n |y_{1:n-1},x_0)$ can be calculated by
# $$p(y_n |y_{1:n-1},x_0) = \underset{\mathcal{X}}{\int}p(y_n |x_n) \cdot p(x_n |y_{1:n-1},x_0) dx_n =
# \mathcal{N}(y_n;HF\mu_{n-1}(x_0),\sigma_y^2 + H(F\sigma_{n-1}^2F^T + \sigma_x^2) H^T) .$$
# Since
# $$1 - \overline{P}(1-\varphi) \hskip0.2cm \leq \hskip0.2cm P(\varphi) \hskip0.2cm \leq  \hskip0.2cm \overline{P}(\varphi)$$
# $$1 - \underset{x_0 \in \mathcal{X}}{sup} [(1- \varphi(x_0))f(x_0 |y_{1:n-1})] \hskip0.2cm \leq
# \hskip0.2cm \underset{\mathcal{X}}{\int} \varphi(x_0)p(x_0 |y_{1:n-1} )dx_0 \hskip0.2cm
# \leq \hskip0.2cm \underset{x_0 \in \mathcal{X}}{sup}\varphi(x_0))f(x_0 |y_{1:n-1}),$$
# By substitute $\varphi(x_0) = p(y_n |y_{1:n-1},x_0) $, we obtain
# <br> <br>
# $$1 - \underset{x_0 \in \mathcal{X}}{sup} [(1-  p(y_n |y_{1:n-1},x_0))f(x_0 |y_{1:n-1})] \hskip0.2cm \leq
# \hskip0.2cm \underset{\mathcal{X}}{\int} p(y_n |y_{1:n-1},x_0)p(x_0 |y_{1:n-1})dx_0 \hskip0.2cm
# \leq \hskip0.2cm \underset{x_0 \in \mathcal{X}}{sup} p(y_n |y_{1:n-1},x_0))f(x_0 |y_{1:n-1})$$
#
# $$\underset{x_0 \in \mathcal{X}}{min} 1 - [(1-  p(y_n |y_{1:n-1},x_0))f(x_0 |y_{1:n-1})] \hskip0.2cm \leq
# \hskip0.2cm p(y_n |y_{1:n-1}) \hskip0.2cm
# \leq \hskip0.2cm \underset{x_0 \in \mathcal{X}}{sup} p(y_n |y_{1:n-1},x_0))f(x_0 |y_{1:n-1}).$$

# %%
#rv-rv case
Mun1  = np.insert(Mun[0:n-1],0,m0) # mean xn-1| y1:n-1 i.e. x0, x1|y1, x2|y1:2, ..., xn-1|y1:n-1
Pnn1  = np.insert(Pnn[0:n-1],0,P0) # var xn-1| y1:n-1
Myn = []
Pyn = []
for i in np.arange(n):
    Myn.append(np.matmul(H,np.matmul(F,[Mun1[i]])))  #mean yn| y1:n-1
    Pyn.append(np.matmul(H,np.matmul(np.matmul(F,np.matmul([Pnn1[i]],F.transpose())) + U, H.transpose())) + V) 
    #var yn| y1:n-1
    
#rv-rv case for prob p(yn|y1:n-1)
cred = []
for i in np.arange(n):
    cred.append((norm(Myn[i],Pyn[i]**0.5).pdf(y[0][i])[0])[0])
    
        
        
#duv-rv case
#yn|x0,y1:n-1
Mcco1  = np.insert(Mcco[0:n-1],0,1) #coef of mean xn-1|x0,y1:n-1 i.e. x0, x1|x0,y1, x2|x0,y1:2, ..., xn-1|x0,y1:n-1 #x0 = 1*x + 0
Mcre1  = np.insert(Mcre[0:n-1],0,0) #remainder of mean xn-1|x0,y1:n-1 
Pc1  = np.insert(Pc[0:n-1],0,P0) #remainder of mean xn-1|x0,y1:n-1 
coyn = []  #coef of mean yn|x0,y1:n-1
reyn = []  #remainder of mean yn|x0,y1:n-1
Pyn = [] #variance yn|x0,y1:n-1
for i in np.arange(n):
    coyn.append(np.matmul(H,np.matmul(F,[Mcco1[i]])))  
    reyn.append(np.matmul(H,np.matmul(F,[Mcre1[i]])))  
    Pyn.append((np.matmul(H,np.matmul(np.matmul(F,np.matmul([Pc1[i]],F.transpose())) + U, H.transpose())) + V)[0]) 
    
#x0|y1:n-1
newMu0 = np.insert(Mu0[0:n-1],0,m0) #mean x0|y1:n-1 i.e. x0, x0|y1, x0|y1:2, ..., x0|y1:n-1
newP00 = np.insert(P00[0:n-1],0,P0) #variance x0|y1:n-1    
    
    
#upper bound for subjective prob p(yn|y1:n-1)
D=[]
for i in np.arange(n):
    def f(x):
        return (math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (norm(coyn[i]*x + reyn[i], Pyn[i]**0.5).pdf(y[0][i]))
    #j1 = minimize(lambda x: -f(x),newMu0[i] + (newP00[i]**0.5)).x   ##set intial guess =m0 +- sig0
    #j2 = minimize(lambda x: -f(x),newMu0[i] - (newP00[i]**0.5)).x
    #fj = max(f(j1),f(j2))
    fj = f(minimize(lambda x: -f(x),newMu0[i]).x)
    D.append(fj[0])  

#lower bound for subjective prob p(yn|y1:n-1)    
Y = [] 
for i in np.arange(n):
    def f(x):
        return 1- ((math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (1-norm(coyn[i]*x + reyn[i], Pyn[i]**0.5).pdf(y[0][i]))) 
    j1 = minimize(f,newMu0[i] + (newP00[i]**0.5)).x  ##set intial guess =m0 +- sig0
    j2 = minimize(f,newMu0[i] - (newP00[i]**0.5)).x
    fj = min(f(j1),f(j2))
    Y.append(fj[0])  
    
#duv-duv case
B =[]#maximum value of function = credibility duv-duv case
for i in np.arange(n):
    def f(x):
        return (math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))*(math.exp((-1/(2*Pyn[i]))*((y[0][i]-coyn[i]*x + reyn[i])**2 )))
    #j1 = minimize(lambda x: -f(x),newMu0[i] + (newP00[i]**0.5)).x   ##set intial guess =m0 +- sig0
    #j2 = minimize(lambda x: -f(x),newMu0[i] - (newP00[i]**0.5)).x
    #fj = max(f(j1),f(j2))
    fj = f(minimize(lambda x: -f(x),newMu0[i]).x)
    B.append(fj)

X = [] #lower bound for credibility duv-duv case
for i in np.arange(n):
    def f(x):
        return 1- ((math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (1-(math.exp((-1/(2*Pyn[i]))*((y[0][i]-coyn[i]*x + reyn[i])**2 ))))) 
    j1 = minimize(f,newMu0[i] + (newP00[i]**0.5)).x  ##set intial guess =m0 +- sig0
    j2 = minimize(f,newMu0[i] - (newP00[i]**0.5)).x
    fj = min(f(j1),f(j2))
    X.append(fj)

# %%
end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("Credibility of $p(y_n| y_{1:n-1})$ for different types of uncertainty when $\sigma_{x_{0}} = 400, \sigma_{x}=1,\sigma_{y}=20$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('credibility', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),cred[0:end],linestyle='-',color='blue',label='rv-rv')
#plt.plot(np.arange(start=1, stop=end+1, step=1),B[0:end],linestyle='-',color='red',label='duv-duv')
#plt.plot(np.arange(start=1, stop=end+1, step=1),X[0:end],linestyle='--',color='red',label='lower bound duv-duv')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),B[0:end],X[0:end], color='red', alpha=0.1,label='range of duv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),D[0:end],linestyle='dashed',color='purple',label='upper bound duv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),Y[0:end],linestyle='dotted',color='purple',label='lower bound duv-rv')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),D[0:end],Y[0:end], color='purple', alpha=0.1,label='range of duv-rv')
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# Try editing lower bound by $\underset{x_0 \in \mathcal{X}}{min} c - [(c-  p(y_n |y_{1:n-1},x_0))f(x_0 | y_{1:n-1} )]$ where
# $c = \underset{x_0 \in \mathcal{X}}{max} \hskip0.2cm p(y_n |y_{1:n-1},x_0)$. <br>
# If $p(y_n |y_{1:n-1},x_0) = \mathcal{N} (y_n ; ax_0 +b,var) $This means that we will choose $x_0 = (y_n -b)/a$

# %%
#another lower bound for subjective prob p(yn|y1:n-1)    
Y = [] 
for i in np.arange(n):
    def f(x):
        c = norm(y[0][i], Pyn[i]**0.5).pdf(y[0][i]) #by substitute x0= (yn - rem )/coef we get mean = yn 
        return c- ((math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (c-norm(coyn[i]*x + reyn[i], Pyn[i]**0.5).pdf(y[0][i])))
    j1 = minimize(f,newMu0[i] + (newP00[i]**0.5)).x  ##set intial guess =m0 +- sig0
    j2 = minimize(f,newMu0[i] - (newP00[i]**0.5)).x
    fj = min(f(j1),f(j2))
    Y.append(fj[0])

# %%
end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("Credibility of $p(y_n| y_{1:n-1})$ for different types of uncertainty when $\sigma_{x_{0}} = 400, \sigma_{x}=1,\sigma_{y}=20$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('credibility', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),cred[0:end],linestyle='-',color='blue',label='rv-rv')
#plt.plot(np.arange(start=1, stop=end+1, step=1),B[0:end],linestyle='-',color='red',label='duv-duv')
#plt.plot(np.arange(start=1, stop=end+1, step=1),X[0:end],linestyle='--',color='red',label='lower bound duv-duv')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),B[0:end],X[0:end], color='red', alpha=0.1,label='range of duv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),D[0:end],linestyle='dashed',color='purple')
plt.plot(np.arange(start=1, stop=end+1, step=1),Y[0:end],linestyle='dotted',color='purple')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),D[0:end],Y[0:end], color='purple', alpha=0.1,label='range of duv-rv')
plt.legend(loc='best',fontsize=15)
plt.show()

# %%
end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("Credibility of $p(y_n| y_{1:n-1})$ for different types of uncertainty when $\sigma_{x_{0}} = 400, \sigma_{x}=1,\sigma_{y}=20$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('credibility', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),cred[0:end],linestyle='-',color='blue',label='rv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),B[0:end],linestyle='dashed',color='red')
plt.plot(np.arange(start=1, stop=end+1, step=1),X[0:end],linestyle='dotted',color='red')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),B[0:end],X[0:end], color='red', alpha=0.1,label='range of duv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),D[0:end],linestyle='dashed',color='purple')
plt.plot(np.arange(start=1, stop=end+1, step=1),Y[0:end],linestyle='dotted',color='purple')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),D[0:end],Y[0:end], color='purple', alpha=0.1,label='range of duv-rv')
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# # Comparison the range of lower bound and upper bound with different type of uncertainty

# %%
end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("Comparison the range of lower bound and upper bound with different type of uncertainty", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('credibility', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),np.array(B[0:end]) - np.array(X[0:end]),linestyle='-',color='red',label='range of possibilistic case')
plt.plot(np.arange(start=1, stop=end+1, step=1),np.array(D[0:end]) - np.array(Y[0:end]),linestyle='-',color='purple',label='range of mixed case')
plt.legend(loc='best',fontsize=15)
plt.show()

# %%
end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("Comparison the ratio of upper bound and lower bound with different type of uncertainty", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('credibility', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),np.array(B[0:end]) / np.array(X[0:end]),linestyle='-',color='red',label='ratio of possibilistic case')
plt.plot(np.arange(start=1, stop=end+1, step=1),np.array(D[0:end]) / np.array(Y[0:end]),linestyle='-',color='purple',label='ratio of mixed case')
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# # try plotting lower bound of $p(y_{8}| y_{1:7})$

# %%
G = []
I = []
J = []
i = 7 #time step that has problem
def f(x):
    c = norm(y[0][i], Pyn[i]**0.5).pdf(y[0][i]) #by substitute x0= (yn - rem )/coef we get mean = yn 
    return c- ((math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (c-norm(coyn[i]*x + reyn[i], Pyn[i]**0.5).pdf(y[0][i])))
for x in np.arange(start=-50, stop=51, step=1):
    G.append(f(x))

# %%
plt.figure(figsize=(30,10))
plt.title("Lower bound of $p(y_{8}| y_{1:7})$ for different types of uncertainty when $\sigma_{x_{0}} = 400, \sigma_{x}=1,\sigma_{y}=20$", fontsize = 20)
plt.xlabel('$x_{0}$',fontsize=20)
plt.ylabel('credibility', fontsize=20)
plt.plot(np.arange(start=-50, stop=51, step=1),G,linestyle='-',color='purple',label='lower bound duv-rv')
plt.vlines(newMu0[i]-newP00[i]**0.5,0,f(newMu0[i]-newP00[i]**0.5),linestyle='--',color='green',label='$m_0 +- \sigma_{0}$')
plt.vlines(newMu0[i]+newP00[i]**0.5,0,f(newMu0[i]+newP00[i]**0.5),linestyle='--',color='green')
plt.vlines(newMu0[i]-2*newP00[i]**0.5,0,f(newMu0[i]-2*newP00[i]**0.5),linestyle='--',color='blue',label='$m_0 +- 2\sigma_{0}$')
plt.vlines(newMu0[i]+2*newP00[i]**0.5,0,f(newMu0[i]+2*newP00[i]**0.5),linestyle='--',color='blue')
plt.vlines(newMu0[i],0,f(newMu0[i]),linestyle='--',color='red',label='$m_0$')
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# # Bayes factor

# %% [markdown]
# ## Model1 : $\mu_0 =0 ,\sigma_0 =400$
# ## Model2 : $\mu_0 =0 ,\sigma_0 =10$(less variance)

# %% [markdown]
# ### Bayes factor : p(y_n| y_{1:n-1},M1) / p(y_n| y_{1:n-1},M2)

# %%
# Prior = N(x0;0,100)
m0 = np.array([0.0]) #m0=0
sig0 =10 #prior sigma , sig0=10
P0 = np.array([sig0**2]) #large uncertainty of initial state sig0^2 

(Mu0,P00,Mun,Pnn,Mcco,Mcre,Pc) = KS(y,m0,P0,F,H,U,V,n,1,n)

#rv-rv case
Mun1  = np.insert(Mun[0:n-1],0,m0) # mean xn-1| y1:n-1 i.e. x0, x1|y1, x2|y1:2, ..., xn-1|y1:n-1
Pnn1  = np.insert(Pnn[0:n-1],0,P0) # var xn-1| y1:n-1
Myn = []
Pyn = []
for i in np.arange(n):
    Myn.append(np.matmul(H,np.matmul(F,[Mun1[i]])))  #mean yn| y1:n-1
    Pyn.append(np.matmul(H,np.matmul(np.matmul(F,np.matmul([Pnn1[i]],F.transpose())) + U, H.transpose())) + V) 
    #var yn| y1:n-1

#duv-rv case
#yn|x0,y1:n-1
Mcco1  = np.insert(Mcco[0:n-1],0,1) #coef of mean xn-1|x0,y1:n-1 i.e. x0, x1|x0,y1, x2|x0,y1:2, ..., xn-1|x0,y1:n-1 #x0 = 1*x + 0
Mcre1  = np.insert(Mcre[0:n-1],0,0) #remainder of mean xn-1|x0,y1:n-1 
Pc1  = np.insert(Pc[0:n-1],0,P0) #remainder of mean xn-1|x0,y1:n-1 
coyn = []  #coef of mean yn|x0,y1:n-1
reyn = []  #remainder of mean yn|x0,y1:n-1
Pyn = [] #variance yn|x0,y1:n-1
for i in np.arange(n):
    coyn.append(np.matmul(H,np.matmul(F,[Mcco1[i]])))  
    reyn.append(np.matmul(H,np.matmul(F,[Mcre1[i]])))  
    Pyn.append((np.matmul(H,np.matmul(np.matmul(F,np.matmul([Pc1[i]],F.transpose())) + U, H.transpose())) + V)[0]) 
    
#x0|y1:n-1
newMu0 = np.insert(Mu0[0:n-1],0,m0) #mean x0|y1:n-1 i.e. x0, x0|y1, x0|y1:2, ..., x0|y1:n-1
newP00 = np.insert(P00[0:n-1],0,P0) #variance x0|y1:n-1

#rv-rv case for prob p(yn|y1:n-1)
cred2 = []
for i in np.arange(n):
    cred2.append(norm(Myn[i],Pyn[i]**0.5).pdf(y[0][i])[0])
    
#upper bound for subjective prob p(yn|y1:n-1)
D2=[]
for i in np.arange(n):
    def f(x):
        return (math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (norm(coyn[i]*x + reyn[i], Pyn[i]**0.5).pdf(y[0][i]))
    #j1 = minimize(lambda x: -f(x),newMu0[i] + (newP00[i]**0.5)).x   ##set intial guess =m0 +- sig0
    #j2 = minimize(lambda x: -f(x),newMu0[i] - (newP00[i]**0.5)).x
    #fj = max(f(j1),f(j2))
    fj = f(minimize(lambda x: -f(x),newMu0[i]).x)
    D2.append(fj[0])  

#lower bound for subjective prob p(yn|y1:n-1)    
Y2 = [] 
for i in np.arange(n):
    def f(x):
        c = norm(y[0][i], Pyn[i]**0.5).pdf(y[0][i]) #by substitute x0= (yn - rem )/coef we get mean = yn 
        return c- ((math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (c-norm(coyn[i]*x + reyn[i], Pyn[i]**0.5).pdf(y[0][i]))) 
    j1 = minimize(f,newMu0[i] + (newP00[i]**0.5)).x  ##set intial guess =m0 +- sig0
    j2 = minimize(f,newMu0[i] - (newP00[i]**0.5)).x
    fj = min(f(j1),f(j2))
    Y2.append(fj[0])  
    
low = np.log10(np.array(Y)/np.array(D2))
up = np.log10(np.array(D)/np.array(Y2))
prob = np.log10(np.array(cred)/np.array(cred2))

end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("log of Bayes factor $log_{10}(K)$ where  $ K= p(y_n| y_{1:n-1},M1) / p(y_n| y_{1:n-1},M2)$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('$log_{10}(K)$', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),prob[0:end],linestyle='-',color='black',label='rv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),up[0:end],linestyle='dashed',color='green',label='upper bound')
plt.plot(np.arange(start=1, stop=end+1, step=1),low[0:end],linestyle='dotted',color='green',label='lower bound')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[min(low[0:end])]*end,[-2]*end, color='red', alpha=0.5,edgecolor= 'none',label='decisive support M2')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-2]*end,[-1]*end, color='red', alpha=0.4,edgecolor= 'none',label='strong support M2')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-1]*end,[-0.5]*end, color='red', alpha=0.3,edgecolor= 'none',label='substantial support M2')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-0.5]*end,[0]*end, color='red', alpha=0.2,edgecolor= 'none',label='weak support M2')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[0]*end,[0.5]*end, color='blue', alpha=0.2,edgecolor= 'none',label='weak support M1')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[0.5]*end,[1]*end, color='blue', alpha=0.3,edgecolor= 'none',label='substantial support M1')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[1]*end,[2]*end, color='blue', alpha=0.4,edgecolor= 'none',label='strong support M1')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[2]*end,[max(up[0:end])]*end, color='blue', alpha=0.5,edgecolor= 'none',label='decisive support M1')
plt.legend(loc='right',fontsize=15)
plt.show()

# %% [markdown]
# ### Bayes factor : p(y_{1:n}|M_1) / p(y_{1:n}|M_2)

# %%
lym1 = [] #lower bound of p(y_{1:n}|M_1) 
lym2 = [] #lower bound of p(y_{1:n}|M_2) 
uym1 = [] #upper bound of p(y_{1:n}|M_1) 
uym2 = [] #upper bound of p(y_{1:n}|M_2)
pym1 = [] #p(y_{1:n}|M_1)
pym2 = [] #p(y_{1:n}|M_2)
for i in np.arange(n):
    lym1.append(np.prod(Y[0:i+1]))
    lym2.append(np.prod(Y2[0:i+1]))
    uym1.append(np.prod(D[0:i+1]))
    uym2.append(np.prod(D2[0:i+1]))
    pym1.append(np.prod(cred[0:i+1]))
    pym2.append(np.prod(cred2[0:i+1]))
LB12 = np.log10(np.array(lym1)/ np.array(uym2)) # lower bound of Bayes factor : p(y_{1:n}|M_1) / p(y_{1:n}|M_2)
UB12 = np.log10(np.array(uym1)/ np.array(lym2)) # lower bound of Bayes factor : p(y_{1:n}|M_1) / p(y_{1:n}|M_2)
B12 = np.log10(np.array(pym1)/ np.array(pym2)) #Bayes factor : p(y_{1:n}|M_1) / p(y_{1:n}|M_2)

end = 50 #end of graph 
plt.figure(figsize=(30,10))
plt.title("log of Bayes factor $log_{10}(K)$ where  $ K= p(y_{1:n}|M1) / p(y_{1:n}|M2)$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('$log_{10}(K)$', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),B12[0:end],linestyle='-',color='black',label='rv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),UB12[0:end],linestyle='dashed',color='green',label='upper bound')
plt.plot(np.arange(start=1, stop=end+1, step=1),LB12[0:end],linestyle='dotted',color='green',label='lower bound')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[min(LB12[0:end])]*end,[-2]*end, color='red', alpha=0.5,edgecolor= 'none',label='decisive support M2')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-2]*end,[-1]*end, color='red', alpha=0.4,edgecolor= 'none',label='strong support M2')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-1]*end,[-0.5]*end, color='red', alpha=0.3,edgecolor= 'none',label='substantial support M2')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-0.5]*end,[0]*end, color='red', alpha=0.2,edgecolor= 'none',label='weak support M2')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[0]*end,[0.5]*end, color='blue', alpha=0.2,edgecolor= 'none',label='weak support M1')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[0.5]*end,[1]*end, color='blue', alpha=0.3,edgecolor= 'none',label='substantial support M1')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[1]*end,[2]*end, color='blue', alpha=0.4,edgecolor= 'none',label='strong support M1')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[2]*end,[max(UB12[0:end])]*end, color='blue', alpha=0.5,edgecolor= 'none',label='decisive support M1')
plt.legend(loc='right',fontsize=15)
plt.show()

# %% [markdown]
# ## Model1 : $\sigma_x =1$
# ## Model3 : $\sigma_x =50$(more variance evolution)

# %% [markdown]
# ### Bayes factor : p(y_n| y_{1:n-1},M1) / p(y_n| y_{1:n-1},M3)

# %%
# Prior = N(x0;0,100)
m0 = np.array([0.0]) #m0=0
sig0 =400 #prior sigma , sig0=400
P0 = np.array([sig0**2]) #large uncertainty of initial state sig0^2 
sigx = 50 #sigx=1
sqrtU = np.array([[sigx]]) #sigma evolve
U = np.matmul(sqrtU, sqrtU.transpose()) #variance evolve
(Mu0,P00,Mun,Pnn,Mcco,Mcre,Pc) = KS(y,m0,P0,F,H,U,V,n,1,n)

#rv-rv case
Mun1  = np.insert(Mun[0:n-1],0,m0) # mean xn-1| y1:n-1 i.e. x0, x1|y1, x2|y1:2, ..., xn-1|y1:n-1
Pnn1  = np.insert(Pnn[0:n-1],0,P0) # var xn-1| y1:n-1
Myn = []
Pyn = []
for i in np.arange(n):
    Myn.append(np.matmul(H,np.matmul(F,[Mun1[i]])))  #mean yn| y1:n-1
    Pyn.append(np.matmul(H,np.matmul(np.matmul(F,np.matmul([Pnn1[i]],F.transpose())) + U, H.transpose())) + V) 
    #var yn| y1:n-1

#duv-rv case
#yn|x0,y1:n-1
Mcco1  = np.insert(Mcco[0:n-1],0,1) #coef of mean xn-1|x0,y1:n-1 i.e. x0, x1|x0,y1, x2|x0,y1:2, ..., xn-1|x0,y1:n-1 #x0 = 1*x + 0
Mcre1  = np.insert(Mcre[0:n-1],0,0) #remainder of mean xn-1|x0,y1:n-1 
Pc1  = np.insert(Pc[0:n-1],0,P0) #remainder of mean xn-1|x0,y1:n-1 
coyn = []  #coef of mean yn|x0,y1:n-1
reyn = []  #remainder of mean yn|x0,y1:n-1
Pyn = [] #variance yn|x0,y1:n-1
for i in np.arange(n):
    coyn.append(np.matmul(H,np.matmul(F,[Mcco1[i]])))  
    reyn.append(np.matmul(H,np.matmul(F,[Mcre1[i]])))  
    Pyn.append((np.matmul(H,np.matmul(np.matmul(F,np.matmul([Pc1[i]],F.transpose())) + U, H.transpose())) + V)[0]) 
    
#x0|y1:n-1
newMu0 = np.insert(Mu0[0:n-1],0,m0) #mean x0|y1:n-1 i.e. x0, x0|y1, x0|y1:2, ..., x0|y1:n-1
newP00 = np.insert(P00[0:n-1],0,P0) #variance x0|y1:n-1

#rv-rv case for prob p(yn|y1:n-1)
cred3 = []
for i in np.arange(n):
    cred3.append(norm(Myn[i],Pyn[i]**0.5).pdf(y[0][i])[0])
    
#upper bound for subjective prob p(yn|y1:n-1)
D3=[]
for i in np.arange(n):
    def f(x):
        return (math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (norm(coyn[i]*x + reyn[i], Pyn[i]**0.5).pdf(y[0][i]))
    #j1 = minimize(lambda x: -f(x),newMu0[i] + (newP00[i]**0.5)).x   ##set intial guess =m0 +- sig0
    #j2 = minimize(lambda x: -f(x),newMu0[i] - (newP00[i]**0.5)).x
    #fj = max(f(j1),f(j2))
    fj = f(minimize(lambda x: -f(x),newMu0[i]).x)
    D3.append(fj[0])  

#lower bound for subjective prob p(yn|y1:n-1)    
Y3 = [] 
for i in np.arange(n):
    def f(x):
        c = norm(y[0][i], Pyn[i]**0.5).pdf(y[0][i]) #by substitute x0= (yn - rem )/coef we get mean = yn 
        return c- ((math.exp((-1/(2*newP00[i]))*((x-newMu0[i])**2 )))* (c-norm(coyn[i]*x + reyn[i], Pyn[i]**0.5).pdf(y[0][i]))) 
    j1 = minimize(f,newMu0[i] + (newP00[i]**0.5)).x  ##set intial guess =m0 +- sig0
    j2 = minimize(f,newMu0[i] - (newP00[i]**0.5)).x
    fj = min(f(j1),f(j2))
    Y3.append(fj[0])  
    
low3 = np.log10(np.array(Y)/np.array(D3))
up3 = np.log10(np.array(D)/np.array(Y3))
prob3 = np.log10(np.array(cred)/np.array(cred3))

end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("log of Bayes factor $log_{10}(K)$ where  $ K= p(y_n| y_{1:n-1},M1) / p(y_n| y_{1:n-1},M3)$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('$log_{10}(K)$', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),prob3[0:end],linestyle='-',color='black',label='rv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),up3[0:end],linestyle='dashed',color='green',label='upper bound')
plt.plot(np.arange(start=1, stop=end+1, step=1),low3[0:end],linestyle='dotted',color='green',label='lower bound')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[min(low3[0:end])]*end,[-2]*end, color='red', alpha=0.5,edgecolor= 'none',label='decisive support M3')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-2]*end,[-1]*end, color='red', alpha=0.4,edgecolor= 'none',label='strong support M3')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-1]*end,[-0.5]*end, color='red', alpha=0.3,edgecolor= 'none',label='substantial support M3')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-0.5]*end,[0]*end, color='red', alpha=0.2,edgecolor= 'none',label='weak support M3')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[0]*end,[0.5]*end, color='blue', alpha=0.2,edgecolor= 'none',label='weak support M1')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[0.5]*end,[1]*end, color='blue', alpha=0.3,edgecolor= 'none',label='substantial support M1')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[1]*end,[2]*end, color='blue', alpha=0.4,edgecolor= 'none',label='strong support M1')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[2]*end,[max(up3[0:end])]*end, color='blue', alpha=0.5,edgecolor= 'none',label='decisive support M1')
plt.legend(loc='right',fontsize=15)
plt.show()

# %% [markdown]
# ### Bayes factor : p(y_{1:n}|M_1) / p(y_{1:n}|M_3)

# %%
lym3 = [] #lower bound of p(y_{1:n}|M_3) 
uym3 = [] #upper bound of p(y_{1:n}|M_3)
pym3 = [] #p(y_{1:n}|M_2)
for i in np.arange(n):
    lym3.append(np.prod(Y3[0:i+1]))
    uym3.append(np.prod(D3[0:i+1]))
    pym3.append(np.prod(cred3[0:i+1]))
LB13 = np.log10(np.array(lym1)/ np.array(uym3)) # lower bound of Bayes factor : p(y_{1:n}|M_1) / p(y_{1:n}|M_3)
UB13 = np.log10(np.array(uym1)/ np.array(lym3)) # lower bound of Bayes factor : p(y_{1:n}|M_1) / p(y_{1:n}|M_3)
B13 = np.log10(np.array(pym1)/ np.array(pym3)) #Bayes factor : p(y_{1:n}|M_1) / p(y_{1:n}|M_3)

end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("log of Bayes factor $log_{10}(K)$ where  $ K= p(y_{1:n}|M1) / p(y_{1:n}|M3)$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('$log_{10}(K)$', fontsize=20)
plt.plot(np.arange(start=1, stop=end+1, step=1),B13[0:end],linestyle='-',color='black',label='rv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),UB13[0:end],linestyle='dashed',color='green',label='upper bound')
plt.plot(np.arange(start=1, stop=end+1, step=1),LB13[0:end],linestyle='dotted',color='green',label='lower bound')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[min(LB13[0:end])]*end,[-2]*end, color='red', alpha=0.5,edgecolor= 'none',label='decisive support M3')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-2]*end,[-1]*end, color='red', alpha=0.4,edgecolor= 'none',label='strong support M3')
#plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-1]*end,[-0.5]*end, color='red', alpha=0.3,edgecolor= 'none',label='substantial support M3')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[-0.5]*end,[0]*end, color='red', alpha=0.2,edgecolor= 'none',label='weak support M3')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[0]*end,[0.5]*end, color='blue', alpha=0.2,edgecolor= 'none',label='weak support M1')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[0.5]*end,[1]*end, color='blue', alpha=0.3,edgecolor= 'none',label='substantial support M1')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[1]*end,[2]*end, color='blue', alpha=0.4,edgecolor= 'none',label='strong support M1')
plt.fill_between(np.arange(start=1, stop=end+1, step=1),[2]*end,[max(UB13[0:end])]*end, color='blue', alpha=0.5,edgecolor= 'none',label='decisive support M1')
plt.legend(loc='right',fontsize=15)
plt.show()

# %%
#try changing format of graph
end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("log of Bayes factor $log_{10}(K)$ where  $ K= p(y_{1:n}|M1) / p(y_{1:n}|M2)$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('$log_{10}(K)$', fontsize=20)
plt.fill_between(np.arange(start=1, stop=end+1, step=1),LB12[0:end],UB12[0:end], color='green', alpha=0.2,edgecolor= 'none',label='range of mixed case')
plt.plot(np.arange(start=1, stop=end+1, step=1),B12[0:end],linestyle='-',color='green',label='rv-rv')
plt.plot(np.arange(start=1, stop=end+1, step=1),[-2]*end,linestyle='dashdot',color='red', alpha=0.4,label='decisive support M2')
plt.plot(np.arange(start=1, stop=end+1, step=1),[-1]*end,linestyle='dashed',color='red', alpha=0.4,label='strong support M2')
plt.plot(np.arange(start=1, stop=end+1, step=1),[-0.5]*end,linestyle='dotted',color='red', alpha=0.4,label='substantial support M2')
plt.plot(np.arange(start=1, stop=end+1, step=1),[0]*end,linestyle='solid',color='purple', alpha=0.4,label='weak support M1/M2')
#plt.plot(np.arange(start=1, stop=end+1, step=1),[0.5]*end,linestyle='dotted',color='blue', alpha=0.4,label='substantial support M1')
#plt.plot(np.arange(start=1, stop=end+1, step=1),[1]*end,linestyle='dashed',color='blue', alpha=0.4,label='strong support M1')
#plt.plot(np.arange(start=1, stop=end+1, step=1),[2]*end,linestyle='dashdot',color='blue', alpha=0.4,label='decisive support M1')
plt.legend(loc='right',fontsize=15)
plt.show()

# %%
#try changing format of graph
end = 30 #end of graph 
plt.figure(figsize=(30,10))
plt.title("log of Bayes factor $log_{10}(K)$ where  $ K= p(y_{1:n}|M1) / p(y_{1:n}|M3)$", fontsize = 20)
plt.xlabel('n',fontsize=20)
plt.ylabel('$log_{10}(K)$', fontsize=20)
plt.fill_between(np.arange(start=1, stop=end+1, step=1),LB13[0:end],UB13[0:end], color='green', alpha=0.2,edgecolor= 'none',label='range of mixed case')
plt.plot(np.arange(start=1, stop=end+1, step=1),B13[0:end],linestyle='-',color='green',label='rv-rv')
#plt.plot(np.arange(start=1, stop=end+1, step=1),[-2]*end,linestyle='dashdot',color='red', alpha=0.4,label='decisive support M3')
#plt.plot(np.arange(start=1, stop=end+1, step=1),[-1]*end,linestyle='dashed',color='red', alpha=0.4,label='strong support M3')
plt.plot(np.arange(start=1, stop=end+1, step=1),[-0.5]*end,linestyle='dotted',color='red', alpha=0.4,label='substantial support M3')
plt.plot(np.arange(start=1, stop=end+1, step=1),[0]*end,linestyle='solid',color='purple', alpha=0.4,label='weak support M1/M3')
plt.plot(np.arange(start=1, stop=end+1, step=1),[0.5]*end,linestyle='dotted',color='blue', alpha=0.4,label='substantial support M1')
plt.plot(np.arange(start=1, stop=end+1, step=1),[1]*end,linestyle='dashed',color='blue', alpha=0.4,label='strong support M1')
plt.plot(np.arange(start=1, stop=end+1, step=1),[2]*end,linestyle='dashdot',color='blue', alpha=0.4,label='decisive support M1')
plt.legend(loc='right',fontsize=15)
plt.show()
